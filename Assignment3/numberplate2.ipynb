# %%
from PIL import Image 

im = Image.open('try2.jpeg.jpg')
 
left = 393
top = 347
right = 590
bottom = 395

im1 = im.crop((left, top, right, bottom)) 
 
im1.save("temp1/car2.jpg")
Image.open("temp1/car2.jpg")
# Out:
# <PIL.JpegImagePlugin.JpegImageFile image mode=RGB size=197x48>

# %%
try:
    from PIL import Image
except ImportError:
    import Image
import pytesseract
img = Image.open("temp1/car2.jpg") 

def ocr_core(img):
    text = pytesseract.image_to_string(Image.open(img))
    return text

print(ocr_core("temp1/car2.jpg"))
# Out:
# MH43CC1745
