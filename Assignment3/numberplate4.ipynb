# %%
from PIL import Image 

im = Image.open('try4.jpg')

left = 511
top = 221
right = 1145
bottom = 440

im1 = im.rotate(-6).crop((left, top, right, bottom))
# im2 = im1.rotate(-7)
im1.save("temp1/car4.jpg")
Image.open("temp1/car4.jpg")
# Out:
# <PIL.JpegImagePlugin.JpegImageFile image mode=RGB size=634x219>

# %%
try:
    from PIL import Image
except ImportError:
    import Image
import pytesseract
img = Image.open("temp1/car4.jpg") 

def ocr_core(img):
    text = pytesseract.image_to_string(Image.open(img))
    return text

print(ocr_core("temp1/car4.jpg"))
# Out:
#
#
# HR26D05591
